# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.dummy import DummyRegressor

# %%
df = pd.read_parquet("full_results.parquet")
df = df[df['Strategy'] != 'No Corpus']
df = df[df['Model'] != 'none']
df = df[df['Corpus Type'] != 'merge']

df['Coverage Delta'] = df.groupby('Function')['Coverage Delta'].transform(lambda x: (x - x.mean()) / x.std())

df = df.dropna(subset=['Coverage Delta'])

# %%
result_rows = []

for func in df['Function'].unique():
    print(f"=== {func} ===")
    df_filtered = df[df['Function'] == func]
    print(len(df_filtered))
    
    columns_to_extract = [ 'Temperature', 'Strategy', 'Model', 'Corpus Type', 'Coverage Delta'] # 'Temperature','Strategy', 'Coverage Delta']

    # Extract the columns and put them in a dictionary with lists
    data = {col: df_filtered[col].tolist() for col in columns_to_extract}
    df_filtered = pd.DataFrame(data)

    # Setting up the features and target variable
    X = df_filtered.drop('Coverage Delta', axis=1)
    y = df_filtered['Coverage Delta']

    # Creating a column transformer to handle categorical variables
    column_transformer = ColumnTransformer(
    [
        ('model_ohe', OneHotEncoder(drop=['GPT-3']), ['Model']),  # Keep all categories for 'Model'
        ('strategy_ohe', OneHotEncoder(drop=['LLM Only']), ['Strategy']),  # Drop first for 'Strategy'
        ('corpus_type_ohe', OneHotEncoder(drop=['simple']), ['Corpus Type'])  # Drop first for 'Corpus Type'
    ],
    remainder='passthrough'
    )

    pipeline = Pipeline(steps=[
        ('preprocessor', column_transformer),
        ('regressor', LinearRegression())
    ])

    # Creating a dummy regressor as the null model
    null_model = DummyRegressor(strategy='mean')#, constant=0 )

    # Splitting data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)#, random_state=4)

    # Fitting the regression model
    pipeline.fit(X_train, y_train)

    # Accessing and printing coefficients and intercept from the linear regression model
    linear_model = pipeline.named_steps['regressor']
    coefficients = linear_model.coef_
    intercept = linear_model.intercept_

    # Get names of the features after transformation
    feature_names = column_transformer.get_feature_names_out()

    print("Intercept:", intercept)
    print("Coefficients:")
    for name, coeff in zip(feature_names, coefficients):
        print(f"{name}: {coeff}")
    print("\n")

    # Fitting the null model
    null_model.fit(X_train, y_train)

    # Predicting on training and test data using the regression model
    y_train_pred = pipeline.predict(X_train)
    y_test_pred = pipeline.predict(X_test)

    # Predicting using the null model
    y_null_pred = null_model.predict(X_test)

    # Evaluating the regression model
    test_mse = mean_squared_error(y_test, y_test_pred)
    test_r2 = r2_score(y_test, y_test_pred)

    # Evaluating the null model
    null_mse = mean_squared_error(y_test, y_null_pred)
    null_r2 = r2_score(y_test, y_null_pred)


    print(f"Test MSE for Regression Model: {test_mse}")
    print(f"Test MSE for Null Model: {null_mse}")

    print(f"Test R^2 for Regression Model: {test_r2}")
    print(f"Test R^2 for Null Model: {null_r2}")
    result_rows.append( [ func,
                          test_mse, null_mse, null_mse - test_mse,
                          test_r2,  abs(null_r2),  test_r2 - null_r2
                        ] )
# Out:
# === PIL.Image.open ===
# 107438
# Intercept: -1.2457272000900845
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.10119814639712633
# model_ohe__Model_Claude-Opus: 0.2062427379370928
# model_ohe__Model_GPT-4: 1.8780682429232658
# model_ohe__Model_Gemini-1.0: 0.30002433738044687
# strategy_ohe__Strategy_LLM + Fuzzing: 0.7465449401614337
# corpus_type_ohe__Corpus Type_complex: 0.11078689386997899
# remainder__Temperature: -0.2823464125624846
#
#
# Test MSE for Regression Model: 0.04576207564562818
# Test MSE for Null Model: 1.0086519995359753
# Test R^2 for Regression Model: 0.9546301496353765
# Test R^2 for Null Model: -6.87563430745719e-06
# === ast.literal_eval ===
# 104422
# Intercept: -1.3942411451653383
# Coefficients:
# model_ohe__Model_Claude-Instant: 1.0398520787981473
# model_ohe__Model_Claude-Opus: 1.1932520050819673
# model_ohe__Model_GPT-4: 0.3386271658389421
# model_ohe__Model_Gemini-1.0: 0.6920233848113272
# strategy_ohe__Strategy_LLM + Fuzzing: 1.899136195176422
# corpus_type_ohe__Corpus Type_complex: -0.37383124898462516
# remainder__Temperature: -0.4990401940656604
#
#
# Test MSE for Regression Model: 0.47578783972028793
# Test MSE for Null Model: 1.0026715919828584
# Test R^2 for Regression Model: 0.5254680670602185
# Test R^2 for Null Model: -2.4903804083598047e-05
# === cgi.parse_header ===
# 101406
# Intercept: -0.27915606348981725
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.26378658652302495
# model_ohe__Model_Claude-Opus: -0.8889239811548776
# model_ohe__Model_GPT-4: 0.40205418406991555
# model_ohe__Model_Gemini-1.0: -0.4935528687651865
# strategy_ohe__Strategy_LLM + Fuzzing: 0.16353410495058346
# corpus_type_ohe__Corpus Type_complex: 0.281031204394759
# remainder__Temperature: -0.10459161879480247
#
#
# Test MSE for Regression Model: 0.8100094542754807
# Test MSE for Null Model: 0.9944020747787966
# Test R^2 for Regression Model: 0.18542629018282175
# Test R^2 for Null Model: -5.3491066800415155e-06
# === cgi.parse_multipart ===
# 51850
# Intercept: -1.5920634301577057
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.577079449134926
# model_ohe__Model_Claude-Opus: 0.8906388848980384
# model_ohe__Model_GPT-4: 0.2531945106482309
# model_ohe__Model_Gemini-1.0: -0.40566831123842995
# strategy_ohe__Strategy_LLM + Fuzzing: 1.4508794508533835
# corpus_type_ohe__Corpus Type_complex: 0.38998373820909177
# remainder__Temperature: -0.14642281034299717
#
#
# Test MSE for Regression Model: 0.7661524113309688
# Test MSE for Null Model: 0.9927099616277617
# Test R^2 for Regression Model: 0.2282202653330686
# Test R^2 for Null Model: -1.3306168715754296e-06
# === configparser.read_string ===
# 50338
# Intercept: -1.2153735184324113
# Coefficients:
# model_ohe__Model_Claude-Instant: 1.0860696748619534
# model_ohe__Model_Claude-Opus: 0.3628069880124254
# model_ohe__Model_GPT-4: 1.9244775030989483
# model_ohe__Model_Gemini-1.0: 1.0813757386213947
# strategy_ohe__Strategy_LLM + Fuzzing: 0.18744683635178838
# corpus_type_ohe__Corpus Type_complex: 0.3785937686521952
# remainder__Temperature: -0.13840188486237406
#
#
# Test MSE for Regression Model: 0.12207523288488394
# Test MSE for Null Model: 0.9987644559459383
# Test R^2 for Regression Model: 0.8777534534502474
# Test R^2 for Null Model: -0.00016606702826216235
# === django.core.deserialize ===
# 48826
# Intercept: -0.42071344682934264
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.5055294249875963
# model_ohe__Model_Claude-Opus: -0.5310800728512726
# model_ohe__Model_GPT-4: 0.6434844833002129
# model_ohe__Model_Gemini-1.0: -0.49222517270873883
# strategy_ohe__Strategy_LLM + Fuzzing: -0.07080656022028328
# corpus_type_ohe__Corpus Type_complex: -0.5233451822800489
# remainder__Temperature: 0.9076629190811379
#
#
# Test MSE for Regression Model: 0.7065514224492754
# Test MSE for Null Model: 1.0103747523275117
# Test R^2 for Regression Model: 0.30068476781822906
# Test R^2 for Null Model: -2.693656064245431e-05
# === email.message_from_string ===
# 89342
# Intercept: -1.7249921729005449
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.43691692676966043
# model_ohe__Model_Claude-Opus: -0.38569160062789865
# model_ohe__Model_GPT-4: 1.4339239295074395
# model_ohe__Model_Gemini-1.0: -0.36479195926105984
# strategy_ohe__Strategy_LLM + Fuzzing: 0.25608516631503697
# corpus_type_ohe__Corpus Type_complex: 0.03764608773201437
# remainder__Temperature: 1.273743866922483
#
#
# Test MSE for Regression Model: 0.28244257224966507
# Test MSE for Null Model: 1.0041781451290097
# Test R^2 for Regression Model: 0.7187117719957785
# Test R^2 for Null Model: -7.406388517616769e-05
# === email.parser.parsebytes ===
# 45802
# Intercept: -1.7573095145470736
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.15428612956641324
# model_ohe__Model_Claude-Opus: 1.7751617607611703
# model_ohe__Model_GPT-4: 1.5729878303632105
# model_ohe__Model_Gemini-1.0: -0.41737164821126665
# strategy_ohe__Strategy_LLM + Fuzzing: 0.4632401744403337
# corpus_type_ohe__Corpus Type_complex: 0.07109309848680181
# remainder__Temperature: 0.928233033758261
#
#
# Test MSE for Regression Model: 0.2365459230332001
# Test MSE for Null Model: 0.9885732925917002
# Test R^2 for Regression Model: 0.7605900455592103
# Test R^2 for Null Model: -0.0005426595644273391
# === email.parser.Parser.parsestr ===
# 83310
# Intercept: -2.2373482801047193
# Coefficients:
# model_ohe__Model_Claude-Instant: -1.059043568923323
# model_ohe__Model_Claude-Opus: -0.4807798560131922
# model_ohe__Model_GPT-4: 0.9550890887709518
# model_ohe__Model_Gemini-1.0: -0.2955446405159481
# strategy_ohe__Strategy_LLM + Fuzzing: 1.3422069530774376
# corpus_type_ohe__Corpus Type_complex: 0.10812435892058947
# remainder__Temperature: 1.0115175034415853
#
#
# Test MSE for Regression Model: 0.23762111958817006
# Test MSE for Null Model: 0.9874828572517631
# Test R^2 for Regression Model: 0.7592844967705968
# Test R^2 for Null Model: -0.0003421973843822368
# === email.utils.parseaddr ===
# 77278
# Intercept: -2.166090954022514
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.35430608246218276
# model_ohe__Model_Claude-Opus: 0.8784596768731214
# model_ohe__Model_GPT-4: 0.9399660948328434
# model_ohe__Model_Gemini-1.0: 0.7406003037320136
# strategy_ohe__Strategy_LLM + Fuzzing: 1.927669952938499
# corpus_type_ohe__Corpus Type_complex: 0.18658092151978647
# remainder__Temperature: 0.006688725381283153
#
#
# Test MSE for Regression Model: 0.21168234041355352
# Test MSE for Null Model: 1.0017787598925088
# Test R^2 for Regression Model: 0.7886845254080204
# Test R^2 for Null Model: -4.2581111296735585e-05
# === email.utils.parsedate ===
# 74262
# Intercept: -2.301366956355605
# Coefficients:
# model_ohe__Model_Claude-Instant: 1.3825191630864355
# model_ohe__Model_Claude-Opus: 1.6205375043892822
# model_ohe__Model_GPT-4: 1.6572954222949379
# model_ohe__Model_Gemini-1.0: 0.4081447306349397
# strategy_ohe__Strategy_LLM + Fuzzing: 1.0794079348790446
# corpus_type_ohe__Corpus Type_complex: 0.20005125195123097
# remainder__Temperature: 0.5159330511470056
#
#
# Test MSE for Regression Model: 0.2603756015914936
# Test MSE for Null Model: 0.9750519619363563
# Test R^2 for Regression Model: 0.7329048555534323
# Test R^2 for Null Model: -0.00021523915629639845
# === exrex.getone ===
# 71246
# Intercept: -1.13284179929464
# Coefficients:
# model_ohe__Model_Claude-Instant: 1.8300712330715803
# model_ohe__Model_Claude-Opus: 1.260994669654309
# model_ohe__Model_GPT-4: 1.7696642672377012
# model_ohe__Model_Gemini-1.0: 1.897396151805954
# strategy_ohe__Strategy_LLM + Fuzzing: 0.23014585797784784
# corpus_type_ohe__Corpus Type_complex: 0.08769362432011615
# remainder__Temperature: -0.13101711552548417
#
#
# Test MSE for Regression Model: 0.26756465026205223
# Test MSE for Null Model: 1.0013535323730516
# Test R^2 for Regression Model: 0.7327729377377025
# Test R^2 for Null Model: -9.011833195882168e-05
# === fnmatch.filter ===
# 68230
# Intercept: -1.1799954452050003
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.43719807601070193
# model_ohe__Model_Claude-Opus: 1.6804376612964178
# model_ohe__Model_GPT-4: 1.1365012542182928
# model_ohe__Model_Gemini-1.0: 0.1459392380611757
# strategy_ohe__Strategy_LLM + Fuzzing: 0.7796817053629158
# corpus_type_ohe__Corpus Type_complex: 0.41739022450958585
# remainder__Temperature: -0.3748369799411059
#
#
# Test MSE for Regression Model: 0.5263301989545893
# Test MSE for Null Model: 1.0048540221500837
# Test R^2 for Regression Model: 0.47621213150280384
# Test R^2 for Null Model: -2.8016298059263534e-07
# === ftplib.FTP ===
# 51192
# Intercept: -1.2641830868294657
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.44027749085038687
# model_ohe__Model_Claude-Opus: 0.37482973496661387
# model_ohe__Model_GPT-4: -0.001044760952882318
# model_ohe__Model_Gemini-1.0: -21.530042537100766
# strategy_ohe__Strategy_LLM + Fuzzing: 1.2777751414235028
# corpus_type_ohe__Corpus Type_complex: -0.0010188316893715726
# remainder__Temperature: 0.012615388936279176
#
#
# Test MSE for Regression Model: 0.6861530526381554
# Test MSE for Null Model: 0.9090404293563855
# Test R^2 for Regression Model: 0.24518742200129395
# Test R^2 for Null Model: -3.056678652857414e-06
# === glob.glob ===
# 63314
# Intercept: -1.0974860082894446
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.2690344483402291
# model_ohe__Model_Claude-Opus: 0.2232636586276162
# model_ohe__Model_GPT-4: -0.31826097004865245
# model_ohe__Model_Gemini-1.0: -1.0692966244245332
# strategy_ohe__Strategy_LLM + Fuzzing: 1.8486632739836355
# corpus_type_ohe__Corpus Type_complex: 0.04675959286517986
# remainder__Temperature: -0.3630121841631111
#
#
# Test MSE for Regression Model: 0.3879197365643297
# Test MSE for Null Model: 1.0099173787440971
# Test R^2 for Regression Model: 0.6158633946861168
# Test R^2 for Null Model: -6.830524829104512e-05
# === html.parser.HTMLParser.feed ===
# 60298
# Intercept: -1.6060987185058282
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.0015481981928441603
# model_ohe__Model_Claude-Opus: 0.11169235813826073
# model_ohe__Model_GPT-4: -3.173743655974446e-05
# model_ohe__Model_Gemini-1.0: 0.09136985842165005
# strategy_ohe__Strategy_LLM + Fuzzing: 1.9669729819179376
# corpus_type_ohe__Corpus Type_complex: 0.13109832939056448
# remainder__Temperature: -0.10313558046584077
#
#
# Test MSE for Regression Model: 0.4251285673279484
# Test MSE for Null Model: 0.9899023727314605
# Test R^2 for Regression Model: 0.5705128802706199
# Test R^2 for Null Model: -5.116463921162051e-05
# === json.loads ===
# 57282
# Intercept: -2.0721355861085957
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.00129795253706045
# model_ohe__Model_Claude-Opus: 0.1264106966096583
# model_ohe__Model_GPT-4: 0.0034950520942716094
# model_ohe__Model_Gemini-1.0: -0.10454549549154489
# strategy_ohe__Strategy_LLM + Fuzzing: 2.5204312942786884
# corpus_type_ohe__Corpus Type_complex: 0.016717344052463074
# remainder__Temperature: 0.004128923644275132
#
#
# Test MSE for Regression Model: 0.05728420666637854
# Test MSE for Null Model: 1.0085164006820977
# Test R^2 for Regression Model: 0.9431994743339028
# Test R^2 for Null Model: -9.607402831068867e-07
# === paramiko.SSHClient.connect ===
# 53630
# Intercept: -1.238737372980998
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.35899292513310765
# model_ohe__Model_Claude-Opus: 0.6335979938217517
# model_ohe__Model_GPT-4: 1.1476247056853324
# model_ohe__Model_Gemini-1.0: -0.2109751377358231
# strategy_ohe__Strategy_LLM + Fuzzing: 0.6698422268259736
# corpus_type_ohe__Corpus Type_complex: 0.17422785555273304
# remainder__Temperature: 0.11622648131405439
#
#
# Test MSE for Regression Model: 0.5512124116313973
# Test MSE for Null Model: 1.0080523319141403
# Test R^2 for Regression Model: 0.4531077994099423
# Test R^2 for Null Model: -0.00015156857375342447
# === plistlib.dumps ===
# 51250
# Intercept: -0.7477165190043721
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.014230845766359633
# model_ohe__Model_Claude-Opus: -2.057093750515971
# model_ohe__Model_GPT-4: 0.5488849936484111
# model_ohe__Model_Gemini-1.0: -1.9959427254732458
# strategy_ohe__Strategy_LLM + Fuzzing: 0.2576255136792303
# corpus_type_ohe__Corpus Type_complex: -0.34819071121579237
# remainder__Temperature: 0.7905574644222818
#
#
# Test MSE for Regression Model: 0.5151264698873694
# Test MSE for Null Model: 0.9611252829355558
# Test R^2 for Regression Model: 0.46395309072137125
# Test R^2 for Null Model: -0.00015873278614608743
# === requests.get ===
# 60924
# Intercept: -1.4192468303376586
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.09656699287775558
# model_ohe__Model_Claude-Opus: 1.5131727407231335
# model_ohe__Model_GPT-4: 2.0945318463019933
# model_ohe__Model_Gemini-1.0: 1.3915165551954276
# strategy_ohe__Strategy_LLM + Fuzzing: 0.09525345149846037
# corpus_type_ohe__Corpus Type_complex: -0.007604807901878791
# remainder__Temperature: 0.43107870789031155
#
#
# Test MSE for Regression Model: 0.03436216295029698
# Test MSE for Null Model: 0.996655488208234
# Test R^2 for Regression Model: 0.9655224391928767
# Test R^2 for Null Model: -2.539076357388481e-06
# === scipy.optimize.minimize ===
# 57908
# Intercept: -2.2724506811680345
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.0017269713047336046
# model_ohe__Model_Claude-Opus: 0.0017261345486896396
# model_ohe__Model_GPT-4: 0.003982540151249603
# model_ohe__Model_Gemini-1.0: 0.0016807457695667653
# strategy_ohe__Strategy_LLM + Fuzzing: 2.7144334266071293
# corpus_type_ohe__Corpus Type_complex: -9.925264719822876e-06
# remainder__Temperature: -0.006206191426814526
#
#
# Test MSE for Regression Model: 0.00015941504389879502
# Test MSE for Null Model: 0.9873077988591226
# Test R^2 for Regression Model: 0.9998385229613383
# Test R^2 for Null Model: -7.838475084520624e-05
# === shlex.split ===
# 54892
# Intercept: -1.9572467267120501
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.2439931909939636
# model_ohe__Model_Claude-Opus: 0.5553485632216986
# model_ohe__Model_GPT-4: 0.2481475541467235
# model_ohe__Model_Gemini-1.0: 0.49599003432996736
# strategy_ohe__Strategy_LLM + Fuzzing: 2.2145036464584655
# corpus_type_ohe__Corpus Type_complex: 0.1436000150147108
# remainder__Temperature: -0.21314437304492678
#
#
# Test MSE for Regression Model: 0.3083243180663742
# Test MSE for Null Model: 1.0121007488296987
# Test R^2 for Regression Model: 0.6953595718943866
# Test R^2 for Null Model: -8.067294635649702e-06
# === smtplib.SMTP ===
# 51876
# Intercept: -0.7970179585920159
# Coefficients:
# model_ohe__Model_Claude-Instant: 2.284339316606032
# model_ohe__Model_Claude-Opus: 0.08976241478076452
# model_ohe__Model_GPT-4: 0.14385115140698995
# model_ohe__Model_Gemini-1.0: 2.729292604624158
# strategy_ohe__Strategy_LLM + Fuzzing: 0.2906301944231543
# corpus_type_ohe__Corpus Type_complex: 0.20755791277225946
# remainder__Temperature: -0.05181978731419612
#
#
# Test MSE for Regression Model: 0.17188842588167155
# Test MSE for Null Model: 1.020740301433392
# Test R^2 for Regression Model: 0.8315587750050414
# Test R^2 for Null Model: -0.0002694823299169702
# === sunau.open ===
# 24700
# Intercept: -0.4682170205310857
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.3186140541761916
# model_ohe__Model_Claude-Opus: -0.0270837251392555
# model_ohe__Model_GPT-4: 1.0039112682107911
# model_ohe__Model_Gemini-1.0: -0.3382407713114523
# strategy_ohe__Strategy_LLM + Fuzzing: 0.05475244733018241
# corpus_type_ohe__Corpus Type_complex: -0.7716996125276113
# remainder__Temperature: 0.7163474358962363
#
#
# Test MSE for Regression Model: 0.5503197529105336
# Test MSE for Null Model: 0.9762542417884201
# Test R^2 for Regression Model: 0.43614931456546435
# Test R^2 for Null Model: -0.00025779645286183595
# === urllib.parse.parse_qs ===
# 45844
# Intercept: -1.9974893629817592
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.09799756699683848
# model_ohe__Model_Claude-Opus: 0.5811741367112324
# model_ohe__Model_GPT-4: 0.8609752785569753
# model_ohe__Model_Gemini-1.0: -0.7895518608308041
# strategy_ohe__Strategy_LLM + Fuzzing: 0.5861153064130882
# corpus_type_ohe__Corpus Type_complex: 0.09240832098194081
# remainder__Temperature: 1.4488198446000686
#
#
# Test MSE for Regression Model: 0.5468860725960241
# Test MSE for Null Model: 0.9863827329956879
# Test R^2 for Regression Model: 0.44551742009396633
# Test R^2 for Null Model: -8.405767214192394e-05
# === urllib.parse.parse_qsl ===
# 42828
# Intercept: -1.073113804845304
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.7168622139301575
# model_ohe__Model_Claude-Opus: 0.9802425564743381
# model_ohe__Model_GPT-4: 1.06616722318902
# model_ohe__Model_Gemini-1.0: -0.7927439049129824
# strategy_ohe__Strategy_LLM + Fuzzing: 0.2265739933698687
# corpus_type_ohe__Corpus Type_complex: 0.6783493545371477
# remainder__Temperature: 0.23746348382922408
#
#
# Test MSE for Regression Model: 0.39689419810764365
# Test MSE for Null Model: 0.9989538715056819
# Test R^2 for Regression Model: 0.6026896521355558
# Test R^2 for Null Model: -1.290219949101612e-06
# === wave.open ===
# 20164
# Intercept: -0.7587650359003091
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.12419041263642795
# model_ohe__Model_Claude-Opus: 1.0739724924682559
# model_ohe__Model_GPT-4: 1.9585844031783208
# model_ohe__Model_Gemini-1.0: 0.11121324808372604
# strategy_ohe__Strategy_LLM + Fuzzing: 0.04771398684749996
# corpus_type_ohe__Corpus Type_complex: -0.04503981028249674
# remainder__Temperature: -0.22825258349813776
#
#
# Test MSE for Regression Model: 0.11013237385741435
# Test MSE for Null Model: 1.0038008705046269
# Test R^2 for Regression Model: 0.890283830659013
# Test R^2 for Null Model: -7.3768999344636654e-06
# === yaml.load ===
# 36796
# Intercept: -1.9550225065517957
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.3911682513616957
# model_ohe__Model_Claude-Opus: 0.580042539002033
# model_ohe__Model_GPT-4: 0.9084276051752821
# model_ohe__Model_Gemini-1.0: -0.09874232453193497
# strategy_ohe__Strategy_LLM + Fuzzing: 1.7471216421823264
# corpus_type_ohe__Corpus Type_complex: 0.21621797202445991
# remainder__Temperature: 0.12450824774622535
#
#
# Test MSE for Regression Model: 0.23153433300219733
# Test MSE for Null Model: 0.9848576963839837
# Test R^2 for Regression Model: 0.7649056105410008
# Test R^2 for Null Model: -8.026161362195694e-07
# === geojson.loads ===
# 30764
# Intercept: -1.1886068851472573
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.39575690425026155
# model_ohe__Model_Claude-Opus: 1.7184010936919967
# model_ohe__Model_GPT-4: 1.2748878479144374
# model_ohe__Model_Gemini-1.0: 1.2426674194881586
# strategy_ohe__Strategy_LLM + Fuzzing: 0.7409135601419435
# corpus_type_ohe__Corpus Type_complex: 0.5195526725925138
# remainder__Temperature: -0.4963853105515055
#
#
# Test MSE for Regression Model: 0.4129695111893116
# Test MSE for Null Model: 0.9880178380191523
# Test R^2 for Regression Model: 0.5820048366736958
# Test R^2 for Null Model: -4.1568160217053673e-05
# === iptcinfo3.IPTCInfo ===
# 27748
# Intercept: -1.1564690031116336
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.06556532519118298
# model_ohe__Model_Claude-Opus: 0.049342178613783094
# model_ohe__Model_GPT-4: 1.9370350322708745
# model_ohe__Model_Gemini-1.0: -0.00634485081604019
# strategy_ohe__Strategy_LLM + Fuzzing: 0.19882883304148588
# corpus_type_ohe__Corpus Type_complex: 0.31586871963108354
# remainder__Temperature: 0.16306737599461318
#
#
# Test MSE for Regression Model: 0.08271762033871885
# Test MSE for Null Model: 0.9951293927653456
# Test R^2 for Regression Model: 0.9168765234267485
# Test R^2 for Null Model: -1.2021962929598118e-05
# === mido.MidiFile ===
# 24732
# Intercept: -0.08600353050049718
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.26987520294587114
# model_ohe__Model_Claude-Opus: 0.7885694728586174
# model_ohe__Model_GPT-4: 1.5151020188889532
# model_ohe__Model_Gemini-1.0: 0.37049492136818774
# strategy_ohe__Strategy_LLM + Fuzzing: 0.04256464492742445
# corpus_type_ohe__Corpus Type_complex: 0.41182825407628165
# remainder__Temperature: -1.041661389700096
#
#
# Test MSE for Regression Model: 0.3250956857871924
# Test MSE for Null Model: 1.023881321914452
# Test R^2 for Regression Model: 0.6822484450328044
# Test R^2 for Null Model: -0.0007511522412277927
# === pandas.read_csv ===
# 21716
# Intercept: -0.34126738448678345
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.024013838096068284
# model_ohe__Model_Claude-Opus: 0.041445091936705314
# model_ohe__Model_GPT-4: 0.3467846236399689
# model_ohe__Model_Gemini-1.0: 0.07018627616286616
# strategy_ohe__Strategy_LLM + Fuzzing: 0.6724120593858721
# corpus_type_ohe__Corpus Type_complex: 0.112956260232897
# remainder__Temperature: -0.43713796668201366
#
#
# Test MSE for Regression Model: 0.8113381747010372
# Test MSE for Null Model: 1.009661095434471
# Test R^2 for Regression Model: 0.19642052336576576
# Test R^2 for Null Model: -5.866784395180957e-06
# === phonenumbers.parse ===
# 18700
# Intercept: -1.3037434852882495
# Coefficients:
# model_ohe__Model_Claude-Instant: -1.068328677239025
# model_ohe__Model_Claude-Opus: 0.702086084061021
# model_ohe__Model_GPT-4: 1.4086145017440546
# model_ohe__Model_Gemini-1.0: 0.47626573436989844
# strategy_ohe__Strategy_LLM + Fuzzing: 0.6556096710744294
# corpus_type_ohe__Corpus Type_complex: 0.1906058158470343
# remainder__Temperature: 0.26396932339861684
#
#
# Test MSE for Regression Model: 0.21049123474450157
# Test MSE for Null Model: 0.9988321831534935
# Test R^2 for Regression Model: 0.7891777798685269
# Test R^2 for Null Model: -0.000402789440553164
# === pydub.AudioSegment.from_file ===
# 6466
# Intercept: -7.936515463002566
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.23187514833609388
# model_ohe__Model_Claude-Opus: -0.30584843318516675
# model_ohe__Model_GPT-4: -0.0011466096462693022
# model_ohe__Model_Gemini-1.0: -2.1106534716564833
# strategy_ohe__Strategy_LLM + Fuzzing: 8.146162402652612
# corpus_type_ohe__Corpus Type_complex: -0.03247920273189765
# remainder__Temperature: -0.21799390009834918
#
#
# Test MSE for Regression Model: 0.4319380463299325
# Test MSE for Null Model: 1.1004412635722984
# Test R^2 for Regression Model: 0.6074828402065706
# Test R^2 for Null Model: -9.336910682167243e-06
# === pyexcel.get_sheet ===
# 26204
# Intercept: -1.8359682661228698
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.15479664885382124
# model_ohe__Model_Claude-Opus: 0.328007512852305
# model_ohe__Model_GPT-4: 0.7314534405478524
# model_ohe__Model_Gemini-1.0: 0.17127016486409427
# strategy_ohe__Strategy_LLM + Fuzzing: 1.9520532899890441
# corpus_type_ohe__Corpus Type_complex: -0.22345156000834893
# remainder__Temperature: 0.10644041167318131
#
#
# Test MSE for Regression Model: 0.35382230553178995
# Test MSE for Null Model: 0.9428149890658499
# Test R^2 for Regression Model: 0.6243936009585955
# Test R^2 for Null Model: -0.0008621205297858481
# === pygments.lex ===
# 23188
# Intercept: -1.9641777159882339
# Coefficients:
# model_ohe__Model_Claude-Instant: -3.6462242628695197e-16
# model_ohe__Model_Claude-Opus: -1.3877787807814457e-16
# model_ohe__Model_GPT-4: 1.205465689331837e-15
# model_ohe__Model_Gemini-1.0: 3.7529214092923864e-16
# strategy_ohe__Strategy_LLM + Fuzzing: 2.47327466078388
# corpus_type_ohe__Corpus Type_complex: 6.140705157133749e-16
# remainder__Temperature: 1.2076698020145685e-16
#
#
# Test MSE for Regression Model: 1.421571828812126e-30
# Test MSE for Null Model: 1.01735374629809
# Test R^2 for Regression Model: 1.0
# Test R^2 for Null Model: -0.00021759150929301363
# === tablib.import_set ===
# 20172
# Intercept: -1.9155219977535005
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.47718323302842997
# model_ohe__Model_Claude-Opus: -0.508422228402011
# model_ohe__Model_GPT-4: 1.0209304599710571
# model_ohe__Model_Gemini-1.0: -0.3771012668264362
# strategy_ohe__Strategy_LLM + Fuzzing: 1.8608169435733215
# corpus_type_ohe__Corpus Type_complex: 0.16143597175635713
# remainder__Temperature: 0.5742822432783715
#
#
# Test MSE for Regression Model: 0.29751444381383335
# Test MSE for Null Model: 1.0723226049539172
# Test R^2 for Regression Model: 0.721916255978402
# Test R^2 for Null Model: -0.0022891022096762637
# === bs4.BeautifulSoup ===
# 17156
# Intercept: -1.2813536353368051
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.44072964651592056
# model_ohe__Model_Claude-Opus: -0.33810432170066274
# model_ohe__Model_GPT-4: -0.3587032783206009
# model_ohe__Model_Gemini-1.0: -0.4635216504894036
# strategy_ohe__Strategy_LLM + Fuzzing: 1.7441494805821576
# corpus_type_ohe__Corpus Type_complex: -0.021996588773646117
# remainder__Temperature: 0.3272902445031511
#
#
# Test MSE for Regression Model: 0.5462577512909066
# Test MSE for Null Model: 1.1169655863802834
# Test R^2 for Regression Model: 0.5108602245226175
# Test R^2 for Null Model: -0.0001730773556709586
# === chardet.detect ===
# 14140
# Intercept: -1.8996649677572028
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.1101223633517504
# model_ohe__Model_Claude-Opus: 0.3599990475219941
# model_ohe__Model_GPT-4: 0.7778287450926651
# model_ohe__Model_Gemini-1.0: -0.07514123891396658
# strategy_ohe__Strategy_LLM + Fuzzing: 2.1039755410721486
# corpus_type_ohe__Corpus Type_complex: 0.0311427024972939
# remainder__Temperature: 0.1773292315842621
#
#
# Test MSE for Regression Model: 0.17219803526017868
# Test MSE for Null Model: 0.9334795456786107
# Test R^2 for Regression Model: 0.8152500130735959
# Test R^2 for Null Model: -0.0015232380532910206
# === html5lib.parse ===
# 30124
# Intercept: -1.4257923026965618
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.49058494443863176
# model_ohe__Model_Claude-Opus: 1.041958408248268
# model_ohe__Model_GPT-4: 2.2492574472075018
# model_ohe__Model_Gemini-1.0: -0.07913835923579182
# strategy_ohe__Strategy_LLM + Fuzzing: 0.3582778297061205
# corpus_type_ohe__Corpus Type_complex: -0.14805052194920792
# remainder__Temperature: 0.34675046193362735
#
#
# Test MSE for Regression Model: 0.025422979262985628
# Test MSE for Null Model: 1.0149292125692657
# Test R^2 for Regression Model: 0.9749501781143807
# Test R^2 for Null Model: -3.212599034685404e-05
# === ics.Calendar ===
# 27108
# Intercept: -1.287697079609591
# Coefficients:
# model_ohe__Model_Claude-Instant: 1.1182464576749604
# model_ohe__Model_Claude-Opus: 0.9043295253480848
# model_ohe__Model_GPT-4: 2.030082340457333
# model_ohe__Model_Gemini-1.0: 0.7129674589194015
# strategy_ohe__Strategy_LLM + Fuzzing: 0.18565570655929148
# corpus_type_ohe__Corpus Type_complex: 0.058503513050897744
# remainder__Temperature: 0.1537296422069517
#
#
# Test MSE for Regression Model: 0.3179154767066994
# Test MSE for Null Model: 1.0076744407645646
# Test R^2 for Regression Model: 0.6844944781701586
# Test R^2 for Null Model: -3.577542507815501e-05
# === markdown.markdown ===
# 21224
# Intercept: -1.5016235648569454
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.28162807830980424
# model_ohe__Model_Claude-Opus: -2.2455729080516926
# model_ohe__Model_GPT-4: -0.7271005811190528
# model_ohe__Model_Gemini-1.0: -0.8559266944003312
# strategy_ohe__Strategy_LLM + Fuzzing: 1.8020428723275244
# corpus_type_ohe__Corpus Type_complex: 0.18604865360501474
# remainder__Temperature: 0.3556934087161411
#
#
# Test MSE for Regression Model: 0.3775977890862878
# Test MSE for Null Model: 0.9415098432542834
# Test R^2 for Regression Model: 0.5988608610733042
# Test R^2 for Null Model: -0.000208313528355486
# === markdown2.markdown ===
# 21076
# Intercept: -1.8017065753113053
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.3913101149919571
# model_ohe__Model_Claude-Opus: -0.7370514401653785
# model_ohe__Model_GPT-4: -0.666946902628978
# model_ohe__Model_Gemini-1.0: -1.719556785248979
# strategy_ohe__Strategy_LLM + Fuzzing: 1.4268798511340954
# corpus_type_ohe__Corpus Type_complex: 0.24147533065873872
# remainder__Temperature: 1.168194881352632
#
#
# Test MSE for Regression Model: 0.5017835103888525
# Test MSE for Null Model: 0.9862271746900733
# Test R^2 for Regression Model: 0.49117101792250173
# Test R^2 for Null Model: -7.465172746612403e-05
# === rarfile.RarFile ===
# 15044
# Intercept: -1.0672576844727206
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.8208317605341572
# model_ohe__Model_Claude-Opus: -0.07842525656148536
# model_ohe__Model_GPT-4: 1.9613350922889374
# model_ohe__Model_Gemini-1.0: -0.07137594837692395
# strategy_ohe__Strategy_LLM + Fuzzing: -0.02487493057458226
# corpus_type_ohe__Corpus Type_complex: 0.38502694121555636
# remainder__Temperature: 0.26665446271505383
#
#
# Test MSE for Regression Model: 0.1826905621705441
# Test MSE for Null Model: 1.0099305984914961
# Test R^2 for Regression Model: 0.8190824277264388
# Test R^2 for Null Model: -0.00012934370030603937
# === simplejson.loads ===
# 12028
# Intercept: -2.3620093941744518
# Coefficients:
# model_ohe__Model_Claude-Instant: -0.07147534128818825
# model_ohe__Model_Claude-Opus: -0.0666923625741993
# model_ohe__Model_GPT-4: 0.14774128399556735
# model_ohe__Model_Gemini-1.0: 0.21429562020748916
# strategy_ohe__Strategy_LLM + Fuzzing: 2.621408620198027
# corpus_type_ohe__Corpus Type_complex: 0.09020461857677896
# remainder__Temperature: 0.027785583301878605
#
#
# Test MSE for Regression Model: 0.13477453927537816
# Test MSE for Null Model: 1.0433760236087986
# Test R^2 for Regression Model: 0.8707598570719809
# Test R^2 for Null Model: -0.0005307170321322552
# === toml.loads ===
# 9012
# Intercept: -0.6789296231704929
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.8119592526519147
# model_ohe__Model_Claude-Opus: 1.2799885216851934
# model_ohe__Model_GPT-4: 1.0609152465834955
# model_ohe__Model_Gemini-1.0: -0.06569218151139107
# strategy_ohe__Strategy_LLM + Fuzzing: 0.606260138933591
# corpus_type_ohe__Corpus Type_complex: 0.21178323063980745
# remainder__Temperature: -0.6399298381511825
#
#
# Test MSE for Regression Model: 0.5853414706268156
# Test MSE for Null Model: 0.9722618945746041
# Test R^2 for Regression Model: 0.39785070655749355
# Test R^2 for Null Model: -0.0001799671433533323
# === xlrd.open_workbook ===
# 5996
# Intercept: -0.7155108119029052
# Coefficients:
# model_ohe__Model_Claude-Instant: -1.7422130492349122
# model_ohe__Model_Claude-Opus: -0.4583785317163639
# model_ohe__Model_GPT-4: -0.06114515948626962
# model_ohe__Model_Gemini-1.0: -0.42837682094554913
# strategy_ohe__Strategy_LLM + Fuzzing: 0.08491269541225809
# corpus_type_ohe__Corpus Type_complex: -0.26208074629157135
# remainder__Temperature: 1.4049694174848582
#
#
# Test MSE for Regression Model: 0.6010377649599008
# Test MSE for Null Model: 1.0305965040980496
# Test R^2 for Regression Model: 0.4165114635116406
# Test R^2 for Null Model: -0.0005049282158002821
# === yaml.safe_load ===
# 2980
# Intercept: -2.0843818561114076
# Coefficients:
# model_ohe__Model_Claude-Instant: 0.10188014900774142
# model_ohe__Model_Claude-Opus: 0.31665180688007344
# model_ohe__Model_GPT-4: 1.5365563877680521
# model_ohe__Model_Gemini-1.0: -0.06170925911088947
# strategy_ohe__Strategy_LLM + Fuzzing: 2.008223514267395
# corpus_type_ohe__Corpus Type_complex: 0.31648902219788705
# remainder__Temperature: 0.18817542114589988
#
#
# Test MSE for Regression Model: 0.13272704155737944
# Test MSE for Null Model: 1.0392520519434245
# Test R^2 for Regression Model: 0.872223878666442
# Test R^2 for Null Model: -0.00048637208465773796

# %%
df_results = pd.DataFrame(result_rows, columns = ["function", "test_mse", "null_mse", "diff_mse", "test_r2",  "null_r2",  "diff_r2"])

# %%
# Create entries for LaTeX table
for index, row in df_results.iterrows():
    fname = row['function'].replace('_', '\_')
    print(f"{fname} & "
          f"{row['test_mse']:.2f} & {row['null_mse']:.2f} & "
          f"{row['test_r2']:.2f} \\\\")
# Out:
# PIL.Image.open & 0.05 & 1.01 & 0.95 \\
# ast.literal\_eval & 0.48 & 1.00 & 0.53 \\
# cgi.parse\_header & 0.81 & 0.99 & 0.19 \\
# cgi.parse\_multipart & 0.77 & 0.99 & 0.23 \\
# configparser.read\_string & 0.12 & 1.00 & 0.88 \\
# django.core.deserialize & 0.71 & 1.01 & 0.30 \\
# email.message\_from\_string & 0.28 & 1.00 & 0.72 \\
# email.parser.parsebytes & 0.24 & 0.99 & 0.76 \\
# email.parser.Parser.parsestr & 0.24 & 0.99 & 0.76 \\
# email.utils.parseaddr & 0.21 & 1.00 & 0.79 \\
# email.utils.parsedate & 0.26 & 0.98 & 0.73 \\
# exrex.getone & 0.27 & 1.00 & 0.73 \\
# fnmatch.filter & 0.53 & 1.00 & 0.48 \\
# ftplib.FTP & 0.69 & 0.91 & 0.25 \\
# glob.glob & 0.39 & 1.01 & 0.62 \\
# html.parser.HTMLParser.feed & 0.43 & 0.99 & 0.57 \\
# json.loads & 0.06 & 1.01 & 0.94 \\
# paramiko.SSHClient.connect & 0.55 & 1.01 & 0.45 \\
# plistlib.dumps & 0.52 & 0.96 & 0.46 \\
# requests.get & 0.03 & 1.00 & 0.97 \\
# scipy.optimize.minimize & 0.00 & 0.99 & 1.00 \\
# shlex.split & 0.31 & 1.01 & 0.70 \\
# smtplib.SMTP & 0.17 & 1.02 & 0.83 \\
# sunau.open & 0.55 & 0.98 & 0.44 \\
# urllib.parse.parse\_qs & 0.55 & 0.99 & 0.45 \\
# urllib.parse.parse\_qsl & 0.40 & 1.00 & 0.60 \\
# wave.open & 0.11 & 1.00 & 0.89 \\
# yaml.load & 0.23 & 0.98 & 0.76 \\
# geojson.loads & 0.41 & 0.99 & 0.58 \\
# iptcinfo3.IPTCInfo & 0.08 & 1.00 & 0.92 \\
# mido.MidiFile & 0.33 & 1.02 & 0.68 \\
# pandas.read\_csv & 0.81 & 1.01 & 0.20 \\
# phonenumbers.parse & 0.21 & 1.00 & 0.79 \\
# pydub.AudioSegment.from\_file & 0.43 & 1.10 & 0.61 \\
# pyexcel.get\_sheet & 0.35 & 0.94 & 0.62 \\
# pygments.lex & 0.00 & 1.02 & 1.00 \\
# tablib.import\_set & 0.30 & 1.07 & 0.72 \\
# bs4.BeautifulSoup & 0.55 & 1.12 & 0.51 \\
# chardet.detect & 0.17 & 0.93 & 0.82 \\
# html5lib.parse & 0.03 & 1.01 & 0.97 \\
# ics.Calendar & 0.32 & 1.01 & 0.68 \\
# markdown.markdown & 0.38 & 0.94 & 0.60 \\
# markdown2.markdown & 0.50 & 0.99 & 0.49 \\
# rarfile.RarFile & 0.18 & 1.01 & 0.82 \\
# simplejson.loads & 0.13 & 1.04 & 0.87 \\
# toml.loads & 0.59 & 0.97 & 0.40 \\
# xlrd.open\_workbook & 0.60 & 1.03 & 0.42 \\
# yaml.safe\_load & 0.13 & 1.04 & 0.87 \\

# %%
averages = df_results[['test_mse', 'null_mse', 'diff_mse', 'test_r2', 'null_r2', 'diff_r2']].mean()

# Print the averages formatted to two decimal places
print("Column Averages:")
for column, value in averages.items():
    print(f"{column}: {value:.2f}")
# Out:
# Column Averages:
# test_mse: 0.34
# null_mse: 1.00
# diff_mse: 0.66
# test_r2: 0.66
# null_r2: 0.00
# diff_r2: 0.66

# %%
# Start the LaTeX formula with the intercept
formula = f"y = {intercept:.2f} "

# Add each coefficient and its corresponding feature name
for coeff, name in zip(coefficients, feature_names):
    if coeff >= 0: formula += f" + {coeff:.2f}{name}"
    else: formula += f" - {abs(coeff):.2f}*{name}"
formula
# Out:
# 'y = -2.08  + 0.10model_ohe__Model_Claude-Instant + 0.32model_ohe__Model_Claude-Opus + 1.54model_ohe__Model_GPT-4 - 0.06*model_ohe__Model_Gemini-1.0 + 2.01strategy_ohe__Strategy_LLM + Fuzzing + 0.32corpus_type_ohe__Corpus Type_complex + 0.19remainder__Temperature'
